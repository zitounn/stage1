# %%
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
import numpy as np

# %%
my_data = genfromtxt('delte_this.csv', delimiter=',')

# %%
my_data[:,[0]].shape
# Out:
# (188, 1)

# %%
x = np.arange(len(my_data))

plt.plot(x, my_data[:,[0]])
plt.plot(x, my_data[:,[1]])
plt.show()
